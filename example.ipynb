# %%
from TSMetrics import *

# %%
import numpy as np
M = 100
x = np.linspace(-np.pi,np.pi,M)
y_true = 3.4*np.sin(x)
N = 10**4
y_pred = np.array([np.random.choice(np.linspace(2.4,3.8,M))*np.sin(x) for _ in range(N)])
ts_metrics = TSMetrics(y_true,y_pred)

# %%
data = ts_metrics.compute_standard_metrics_summary()

# %%
data
# Out:
#                        mae       mse      rmse  \
# Time Series 0     0.621289  0.481099  0.693613
# Time Series 1     0.309371  0.119291  0.345385
# Time Series 2     0.113309  0.016002  0.126499
# Time Series 3     0.198609  0.049164  0.221729
# Time Series 4     0.047106  0.002766   0.05259
# ...                    ...       ...       ...
# Time Series 9995  0.086573  0.009341  0.096651
# Time Series 9996  0.148957  0.027655  0.166297
# Time Series 9997  0.318283  0.126263  0.355335
# Time Series 9998  0.011458  0.000164  0.012792
# Time Series 9999  0.157868  0.031063  0.176246
#
#                                                                msle  \
# Time Series 0     Error: Mean Squared Logarithmic Error cannot b...
# Time Series 1     Error: Mean Squared Logarithmic Error cannot b...
# Time Series 2     Error: Mean Squared Logarithmic Error cannot b...
# Time Series 3     Error: Mean Squared Logarithmic Error cannot b...
# ...
