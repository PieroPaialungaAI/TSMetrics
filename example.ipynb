# %%
from TSMetrics import TimeSeriesComparison
from TSAnalyzer import TimeSeriesAnalyzer
import numpy as np

M = 100
x = np.linspace(-np.pi,np.pi,M)
y_true = np.abs(3.4*np.sin(x))
N = 10
y_pred = np.abs(np.array([np.random.choice(np.linspace(-5.0,5.0,M))*np.sin(x) for _ in range(N)]))
ts_metrics = TimeSeriesAnalyzer(y_true)

# %%
ts_metrics.clean_noise()
# Out:
# (array([-0.17051499,  0.11072754,  0.37988903,  0.63700525,  0.88211199,
#          1.11524503,  1.33644015,  1.54573314,  1.74315976,  1.92875582,
#          2.10255708,  2.26459933,  2.41491834,  2.55354991,  2.68052982,
#          2.79589383,  2.89967775,  2.99191734,  3.07264838,  3.14190667,
#          3.19972798,  3.24614809,  3.28120279,  3.30492785,  3.31735906,
#          3.3185322 ,  3.29247335,  3.24520596,  3.17916829,  3.0967765 ,
#          3.00041481,  2.89242599,  2.77510187,  2.65067415,  2.52130539,
#          2.3890803 ,  2.25599737,  2.12396079,  1.99477282,  1.87012648,
#          1.75159881,  1.64064443,  1.53858977,  1.44662764,  1.36581252,
#          1.29705624,  1.24112435,  1.198633  ,  1.17004651,  1.15567547,
#          1.15567547,  1.17004651,  1.198633  ,  1.24112435,  1.29705624,
#          1.36581252,  1.44662764,  1.53858977,  1.64064443,  1.75159881,
#          1.87012648,  1.99477282,  2.12396079,  2.25599737,  2.3890803 ,
# ...

# %%
import numpy as np 
x = np.array([0,0,np.nan, -1,-1])

# %%
np.nan_to_num(x,nan = np.nanmean(x))
# Out:
# array([ 0. ,  0. , -0.5, -1. , -1. ])
